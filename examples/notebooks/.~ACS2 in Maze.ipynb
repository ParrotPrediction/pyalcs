# %% [markdown]
# # ACS2 in Maze Experiments
# The following notebooks provides reproducible playground for experimenting how ACS2 agent behaves inside Maze environments.
#
# ## Checklist:
# - check if classifiers with $q < 0.1$ are deleted,
# - [ALP] - parameters update process,
# - **Deletion of classifiers** - I think we are loosing good classifiers along the way
# - ALP expected case
# - ALP covering
# - RL what is `maxP`
#
# Butz notes:
# - ACS2 should start with initially empty classifiers list (what does it mean)?
# - second learning should be triggered after successful step of finding reward?
# - set_mark should mark the whole perception (probably not only changing parts) (unexpected case ACS2 p9)
#
# TODO:
# - set_mark copies whole perception (not indivudial points). But will it make any difference?
# - explicitly divide into exploration / exploitation after certain number of steps
# - check order of arguments in `apply_alp(...)` runs (main loop)
#
# ## My modifications
# - behaviour policy strategies,
# - dynamic exploration rate,
# - offspring is not marked,

# %% [markdown]
# ## Imports and configuration
# Load project files from upper directory (nasty solution).

# %%
import sys
sys.path.append('/home/norbert/Projects/pyalcs')

# %% [markdown]
# Import `pyalcs` module

# %%
# Enable automatic module reload
# %load_ext autoreload
# %autoreload 2

from alcs.agent.acs2 import ACS2
from alcs.environment.maze import Maze

# Metrics
from alcs.helpers.metrics import \
    ActualStep,\
    ClassifierPopulationSize,\
    ReliableClassifierPopulationSize,\
    AveragedFitnessScore,\
    SuccessfulTrial,\
    AveragedConditionSpecificity,\
    AchievedKnowledge

# Helpers
from alcs.helpers.maze_utils import calculate_optimal_path_length

# %% [markdown]
# Other helpers

# %%
# %matplotlib inline

from concurrent.futures import ProcessPoolExecutor, as_completed

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Experiment
# We are going to test ACS2 **agent** inside **maze** environment. The agent will have 2 tasks:
# 1. learn the shortest path to the goal state,
# 2. learn the internal model of the environment

# %% [markdown]
# ### Maze
# Currently there are 4 mazes implemented:
# - `mazes/MazeF1.maze` (deterministic),
# - `mazes/MazeF2.maze` (deterministic),
# - `mazes/MazeF3.maze` (deterministic),
# - `mazes/MazeF4.maze` (non-deterministic)
# - `mazes/Maze5.maze` (deterministic)
#
# Maze `MazeF4` introduces also the *aliasing* problem - the are two states that looks exactly the same for an agent.

# %%
# Location of the maze file
MAZE_LOCATION = 'mazes/MazeF3.maze'

# %% [markdown]
# And visualize it

# %%
env = Maze(MAZE_LOCATION)

fig = plt.figure(figsize=(env.max_x, env.max_y))
ax = fig.add_subplot(111, aspect='equal')

# Render maze as image
plt.imshow(env.matrix, interpolation='none', cmap='Set3', aspect='auto',
           extent=[0, env.max_x, env.max_y, 0])

# Add labels to each cell
for x in range(0, env.max_x):
    for y in range(0, env.max_y):
        plt.text(x+0.4, y+0.5, env.matrix[y][x])

ax.set_title(MAZE_LOCATION)
ax.set_xlabel('x')
ax.set_ylabel('y')

plt.xlim(0, env.max_x)
plt.ylim(env.max_y, 0)

plt.xticks(range(0, env.max_x))
plt.yticks(range(0, env.max_y))

plt.grid(True)
plt.show()

# %% [markdown]
# **Legend / reward map**:
# - `0` is a $wall$ (cannot cross),
# - `1` is a $path$ (reward $\rho = 0$),
# - `9` is a $price$ (reward $\rho = 1000$)

# %% [markdown]
# ### Optimal number of steps

# %%
optimal_numer_of_steps = calculate_optimal_path_length(env)
print("Optimal number of steps to reward: {:.2f}".format(optimal_numer_of_steps))
# Out:
# Optimal number of steps to reward: 3.38

# %% [markdown]
# ### Agent
# Agent interacts autonomously with the environment.
#
# In this notebook it moves in maze for the certain number of steps.
#
# > **Trial** is a successful run of agent when he manages to find the reward. After learning it should take him less and less steps to reach the goal.
#
# At the beginning of each trial an agent is randomly placed inside the maze.
# He can perceive 8 values (neighbourhood cells - N, NE, E, SE, S, SW, W, NW) and also move in 8 directions (N, NE, E, SE, S, SW, W, NW).

# %% [markdown]
# ### Run the simulation
# The whole simulation will run a certain number of times for certain number of steps.

# %%
# Number of experiments
EXPERIMENTS = 1

# Number of agent steps for each experiment
STEPS = 12000 # 10 000

# Amount of processes pool
PROCESSES = 2

# Use last half of steps for pure exploitation
EXPLOITATION_MODE = True

# Biased exploration strategy probability
EPSILON = 0.5

# %% [markdown]
# Let's declare a function performing a single experiment.
#
# We are:
# 1. initializing an agent,
# 2. instructing him to collect specified measurements,
# 3. initializing the environment,
# 4. running the simulation,
# 5. returning obtained classifiers and metrics

# %%
def perform_experiment(experiment):
    # Initialize the agent
    agent = ACS2(epsilon=EPSILON, exploitation_mode=EXPLOITATION_MODE)
    
    agent.add_metrics_handlers([
        ActualStep('time'),
        SuccessfulTrial('found_reward'),
        ClassifierPopulationSize('total_classifiers'),
        ReliableClassifierPopulationSize('reliable_classifiers'),
        AveragedFitnessScore('average_fitness'),
        AveragedConditionSpecificity('average_specificity'),
        AchievedKnowledge('achieved_knowledge')
    ])

    # Initialize the environment
    env = Maze(MAZE_LOCATION)

    # Evaluate algorithm
    classifiers, metrics = agent.evaluate(env, STEPS)

    # Add information about the experiment into metrics
    metrics['experiment_id'] = [experiment] * len(metrics['time'])

    return classifiers, metrics

# %% [markdown]
# Then firing many jobs in parallel.

# %%
all_classifiers = []
all_metrics = pd.DataFrame()

with ProcessPoolExecutor(PROCESSES) as executor:
    futures = []

    for i in range(EXPERIMENTS):
        future = executor.submit(perform_experiment, i)
        futures.append(future)

    for idx, el in enumerate(as_completed(futures)):
        classifiers, metrics = el.result()

        all_classifiers.append(classifiers)
        all_metrics = all_metrics.append(pd.DataFrame(metrics))

# %% [markdown]
# We can also inspect how the classifier population looks. Internal model of the environment is specified only by reliable classifiers.

# %%
## take classifiers from the first experiment
classifiers = all_classifiers[0]

# Select only 'reliable' ones
reliable = [c for c in classifiers if c.is_reliable()]
reliable.sort(key=lambda cls: cls.action)

print("All macro-classifiers: {} (micro-classifiers: {})"
      .format(len(classifiers), sum(cl.num for cl in classifiers)))

print("Reliable macro-classifiers: {} (micro-classifiers: {})\n"
      .format(len(reliable), sum(cl.num for cl in reliable)))

for cls in reliable:
    print(cls)
# Out:
# All macro-classifiers: 203 (micro-classifiers: 520)
# Reliable macro-classifiers: 45 (micro-classifiers: 246)
#
# Classifier{0#9##### ↑ ######## q:0.99, r:7984.74, ir:0.00}
# Classifier{##9##0## ↑ ######## q:1.00, r:7965.27, ir:0.00}
# Classifier{0#0##### ↑ ######## q:0.97, r:3458.98, ir:0.00}
# Classifier{####00## ↗ ######## q:1.00, r:3371.59, ir:0.00}
# Classifier{#09##### ↗ ######## q:0.92, r:6506.82, ir:0.00}
# Classifier{1#10#00# ↗ #101#111 q:0.98, r:3642.53, ir:0.00}
# Classifier{1#1##00# ↗ #101#111 q:0.97, r:3634.94, ir:0.00}
# Classifier{#010#000 ↗ #101#111 q:1.00, r:3582.74, ir:0.00}
# Classifier{#0101000 ↗ #101#111 q:0.99, r:3593.75, ir:0.00}
# Classifier{10101000 ↗ #101#111 q:0.94, r:3596.48, ir:0.00}
# Classifier{##01#### ↗ #101#111 q:0.93, r:3635.34, ir:0.00}
# Classifier{####0#0# → ######## q:0.95, r:3370.03, ir:0.02}
# Classifier{#1#0#### → ######## q:0.99, r:3465.35, ir:18.04}
# Classifier{##1##1#1 → ##0##0#0 q:1.00, r:3050.22, ir:0.00}
# Classifier{##9##### → ##0##### q:1.00, r:10775.00, ir:1000.00}
# Classifier{##9####0 → ##0##### q:0.99, r:10707.69, ir:980.82}
# Classifier{#090#### → ##0##### q:0.99, r:10508.54, ir:945.02}
# Classifier{1###1000 → 0###0111 q:1.00, r:3382.96, ir:0.53}
# Classifier{1##01000 → 0###0111 q:1.00, r:3402.53, ir:2.57}
# Classifier{10##1000 → 0###0111 q:1.00, r:3365.42, ir:0.00}
# Classifier{##90#### ↘ ######## q:1.00, r:7664.57, ir:0.00}
# Classifier{####11## ↘ ######## q:0.96, r:4876.50, ir:0.00}
# Classifier{0#10#00# ↘ 1101#111 q:0.97, r:3692.42, ir:0.00}
# Classifier{0010#000 ↘ 1101#111 q:1.00, r:3622.07, ir:0.00}
# Classifier{0##0#000 ↘ 1101#111 q:0.94, r:3622.07, ir:0.00}
# Classifier{00101000 ↘ 1101#111 q:0.96, r:3562.25, ir:0.00}
# Classifier{101#1##0 ↓ #10#0### q:1.00, r:3410.21, ir:0.00}
# Classifier{101##### ↓ #10#0### q:0.94, r:3407.16, ir:0.00}
# Classifier{#101#0## ↓ #010#### q:1.00, r:3578.73, ir:0.00}
# Classifier{###1#0## ↓ #010#### q:0.97, r:3590.67, ir:0.00}
# Classifier{##01#0## ↓ #010#### q:0.95, r:3584.70, ir:0.00}
# Classifier{#101###0 ↓ #010#### q:0.98, r:3497.74, ir:0.00}
# Classifier{####01## ↓ ######## q:0.95, r:3448.93, ir:0.00}
# Classifier{0#0#0### ↙ ######## q:0.98, r:3262.42, ir:0.00}
# Classifier{##00##11 ← ######00 q:0.95, r:3566.15, ir:0.00}
# Classifier{##9##0## ← ##1##1## q:0.95, r:7094.75, ir:0.00}
# Classifier{##00#0#0 ← ##1##1#1 q:0.99, r:3347.87, ir:0.00}
# Classifier{110##111 ↖ 0010#000 q:0.99, r:3513.97, ir:0.00}
# Classifier{110##1#1 ↖ 0010#000 q:0.99, r:3513.97, ir:0.00}
# Classifier{1#0##1#1 ↖ 0010#000 q:0.99, r:3511.06, ir:0.00}
# Classifier{1101#111 ↖ 0010#000 q:1.00, r:3505.83, ir:0.00}
# Classifier{1#0##11# ↖ 0010#000 q:0.98, r:3505.83, ir:0.00}
# Classifier{0##0#### ↖ ######## q:1.00, r:3308.29, ir:0.00}
# Classifier{#101#1#1 ↖ 0010#000 q:0.91, r:3509.90, ir:0.00}
# Classifier{#1#1#111 ↖ 0010#000 q:0.92, r:3505.83, ir:0.00}

# %% [markdown]
# <p style="color:red">**TODO**: There are duplicate classifiers!!!! Maybe subsumption does not works. Why low quality classifiers are not removed?</p>

# %% [markdown]
# ## Performance metrics
# Let's have a look how the performance metrics look like by taking 5 random samples:

# %%
all_metrics.sample(5)
# Out:
#       achieved_knowledge  average_fitness  average_specificity  experiment_id  \
# 7477            0.333333      2653.330110             0.356527              0
# 3693            0.333333      3329.369869             0.365789              0
# 5476            0.476190      3533.709473             0.344731              0
# 4288            0.238095      2429.915384             0.352099              0
# 6946            0.333333      2653.330110             0.356527              0
#
#      found_reward  reliable_classifiers  time  total_classifiers
# 7477        False                   246  7493                520
# 3693        False                   240  3694                491
# 5476        False                   318  5477                612
# 4288        False                   252  4289                547
# 6946        False                   246  6956                520

# %% [markdown]
# Let's define a helper function for measuring an average value across all experiments:

# %%
def get_avg_per_step(performance, colname):
    avg_metric_per_step = pd.DataFrame(performance.groupby('time')[colname].mean())
    avg_metric_per_step.reset_index(inplace=True)
    return avg_metric_per_step

# %% [markdown]
# ### Number of steps to food
# Measures if the classifier actually *learns* something along the time.
#
# > **Number of steps to food** - How many steps were needed in **each trial** to found the reward.
#
# We need to have a little helper function for operating on obtained measurements.

# %%
def get_avg_number_of_steps_to_food(performance):
    x = pd.DataFrame(performance
                     .groupby('experiment_id')
                     .apply(lambda x: x['found_reward'].cumsum()))
    
    trials_by_experiment = pd.DataFrame(x.stack())
    
    trials_by_experiment.reset_index(inplace=True)
    trials_by_experiment.rename(columns = {'found_reward': 'time', 0: 'trial'},
                                inplace=True)

    # Experiment_id, trial, steps
    steps_per_trial_in_experiment = pd.DataFrame(trials_by_experiment
                                                 .groupby(['experiment_id', 'trial'])
                                                 .size())
    steps_per_trial_in_experiment.reset_index(inplace=True)
    steps_per_trial_in_experiment.rename(columns = {0: 'steps'}, inplace=True)

    # Trial, averaged steps
    averaged_steps_per_trial = pd.DataFrame(steps_per_trial_in_experiment.groupby('trial')['steps'].mean())
    averaged_steps_per_trial.rename(columns = {'steps': 'averaged_steps'}, inplace=True)
    averaged_steps_per_trial.reset_index(inplace=True)
    
    return averaged_steps_per_trial

# %% [markdown]
# Now we can visualize the results

# %%
steps_to_food = get_avg_number_of_steps_to_food(all_metrics)
steps_to_food['MA'] = steps_to_food['averaged_steps'].rolling(window=50).mean()

fig = plt.figure(figsize=(15, 8), dpi=100)

plt.bar(steps_to_food['trial'], steps_to_food['averaged_steps'])
plt.plot(steps_to_food['trial'], steps_to_food['MA'], 'r', linewidth=2.0)
plt.axhline(optimal_numer_of_steps, color='r', linestyle='dashed')

plt.title('Averaged number of steps to food')
plt.xlabel('Trial')
plt.ylabel('Steps')

#plt.ylim([0, 20])
#plt.yscale('log')
plt.grid(True)

plt.show()

# %% [markdown]
# ### Achieved knowledge
# Measures if an agent is *learning* the environment.
#
# > **Achieved knowledge** - test whether or not there is a **reliable classifier** for each transition $(\sigma_{1}, \alpha, \sigma_{2})$ with $\sigma_{1} \neq \sigma_{2}$ that can be applied in $\sigma_{1}$ and anticipates $\sigma_{2}$ correctly.
#
# This metric is calculated after each time-step done by the agent.

# %%
knowledge_per_step = get_avg_per_step(all_metrics, 'achieved_knowledge')
knowledge_per_step['MA'] = knowledge_per_step['achieved_knowledge'].rolling(window=100).mean()

fig = plt.figure(figsize=(15, 8), dpi=100)

plt.plot(knowledge_per_step['time'], knowledge_per_step['achieved_knowledge'], 'b')
plt.plot(knowledge_per_step['time'], knowledge_per_step['MA'], 'r', linewidth=2.0)

plt.title('Averaged achieved knowledge')
plt.xlabel('Step')
plt.ylabel('Achieved knowledge')

plt.ylim([0, 1])

plt.grid(True)

plt.show()

# %% [markdown]
# ### Classifiers
# What is the number of classifiers across steps

# %%
all_classifiers_per_step = get_avg_per_step(all_metrics, 'total_classifiers')
reliable_classifiers_per_step = get_avg_per_step(all_metrics, 'reliable_classifiers')

fig = plt.figure(figsize=(15, 8), dpi=100)

plt.plot(all_classifiers_per_step['time'], all_classifiers_per_step['total_classifiers'], 'r', linewidth=1)
plt.plot(reliable_classifiers_per_step['time'], reliable_classifiers_per_step['reliable_classifiers'], 'b', linewidth=1)
plt.title('Average number of classifiers per step')
plt.xlabel('Step')
plt.ylabel('Number of classifiers')

plt.grid(True)
plt.legend(loc="lower right", shadow=True, title="Legend", fancybox=False)

plt.show()

# %% [markdown]
# ### Specificity measure
# Measure the *generalization* in classifier population.
#
# > **Specificity measure** - Equal to the **sum** of all specialized attributed in condition part of all classifiers in population **divided** by the number of classifiers **times** the length of  the perception $\sigma$.
#
# You can read more about this metric in "*Introducing a Genetic Generalization Pressure to the
# Anticipatory Classfierier System - Part2: Performance Analysis*" by Martin V. Butz.
#
# Plot should change after modifing the agent's *mutation* and *cross over* values. The author claims that the best generalization was reached for mutation rate $\mu = 0.4$.

# %% [markdown]
# Plot the results

# %%
spec_per_step = get_avg_per_step(all_metrics, 'average_specificity')

fig = plt.figure(figsize=(15, 8), dpi=100)

plt.plot(spec_per_step['time'], spec_per_step['average_specificity'], 'r', linewidth=1)
plt.title('Averaged specificity of condition parts for classifiers')
plt.xlabel('Step')
plt.ylabel('Specificity')

plt.grid(True)

plt.show()

# %% [markdown]
# We can observe that the value stabilizes near 0.45 which means most elements of condition part is wildcards.
#
# We can execute another experiment, but this time also the mutation ratio will change.

# %% [markdown]
# The following image presents how the alternative plot can look like:
# ![title](temp/generalization.png)

# %% [markdown]
# Prepare variables for the simulation

# %%
# Create an array containing possible values of mutation rate
mutation_rates = np.linspace(0, 1, 9)

# Number of experiments
EXPERIMENTS = 10

# Number of steps in each experiment
STEPS = 10000

# %% [markdown]
# Run the simulation

# %%
performance = pd.DataFrame()

for experiment in range(EXPERIMENTS):
    print("Experiment: [{}]".format(experiment))
    
    for mutation_rate in mutation_rates:
        print("\tMutation rate: {}".format(mutation_rate))
        
        # Re-initialize the environment
        env = Maze(MAZE_LOCATION)

        # Initialize the agent with metric handler
        agent = ACS2(mu=mutation_rate)
        agent.add_metrics_handlers([
            ActualStep('time'),
            AveragedConditionSpecificity('average_specificity'),
        ])
        
        # Evaluate algorithm
        #classifiers, metrics = agent.evaluate(env, STEPS)

        # Add information about the experiment into metrics
        metrics['experiment_id'] = [experiment] * len(metrics['time'])
        metrics['mutation_rate'] = [mutation_rate] * len(metrics['time'])

        # Append performance metrics
        performance = performance.append(pd.DataFrame(metrics))
# Out:
# Experiment: [0]
# 	Mutation rate: 0.0
# 	Mutation rate: 0.125
# 	Mutation rate: 0.25
# 	Mutation rate: 0.375
# 	Mutation rate: 0.5
# 	Mutation rate: 0.625
# 	Mutation rate: 0.75
# 	Mutation rate: 0.875
# 	Mutation rate: 1.0
# Experiment: [1]
# 	Mutation rate: 0.0
# 	Mutation rate: 0.125
# 	Mutation rate: 0.25
# 	Mutation rate: 0.375
# 	Mutation rate: 0.5
# 	Mutation rate: 0.625
# 	Mutation rate: 0.75
# 	Mutation rate: 0.875
# 	Mutation rate: 1.0
# Experiment: [2]
# 	Mutation rate: 0.0
# 	Mutation rate: 0.125
# 	Mutation rate: 0.25
# 	Mutation rate: 0.375
# 	Mutation rate: 0.5
# 	Mutation rate: 0.625
# 	Mutation rate: 0.75
# 	Mutation rate: 0.875
# 	Mutation rate: 1.0
# Experiment: [3]
# 	Mutation rate: 0.0
# 	Mutation rate: 0.125
# 	Mutation rate: 0.25
# 	Mutation rate: 0.375
# 	Mutation rate: 0.5
# 	Mutation rate: 0.625
# 	Mutation rate: 0.75
# 	Mutation rate: 0.875
# 	Mutation rate: 1.0
# Experiment: [4]
# 	Mutation rate: 0.0
# 	Mutation rate: 0.125
# 	Mutation rate: 0.25
# 	Mutation rate: 0.375
# 	Mutation rate: 0.5
# 	Mutation rate: 0.625
# 	Mutation rate: 0.75
# 	Mutation rate: 0.875
# 	Mutation rate: 1.0
# Experiment: [5]
# 	Mutation rate: 0.0
# 	Mutation rate: 0.125
# 	Mutation rate: 0.25
# 	Mutation rate: 0.375
# 	Mutation rate: 0.5
# 	Mutation rate: 0.625
# 	Mutation rate: 0.75
# 	Mutation rate: 0.875
# 	Mutation rate: 1.0
# Experiment: [6]
# 	Mutation rate: 0.0
# 	Mutation rate: 0.125
# 	Mutation rate: 0.25
# 	Mutation rate: 0.375
# 	Mutation rate: 0.5
# 	Mutation rate: 0.625
# 	Mutation rate: 0.75
# 	Mutation rate: 0.875
# 	Mutation rate: 1.0
# Experiment: [7]
# 	Mutation rate: 0.0
# 	Mutation rate: 0.125
# 	Mutation rate: 0.25
# 	Mutation rate: 0.375
# 	Mutation rate: 0.5
# 	Mutation rate: 0.625
# 	Mutation rate: 0.75
# 	Mutation rate: 0.875
# 	Mutation rate: 1.0
# Experiment: [8]
# 	Mutation rate: 0.0
# 	Mutation rate: 0.125
# 	Mutation rate: 0.25
# 	Mutation rate: 0.375
# 	Mutation rate: 0.5
# 	Mutation rate: 0.625
# 	Mutation rate: 0.75
# 	Mutation rate: 0.875
# 	Mutation rate: 1.0
# Experiment: [9]
# 	Mutation rate: 0.0
# 	Mutation rate: 0.125
# 	Mutation rate: 0.25
# 	Mutation rate: 0.375
# 	Mutation rate: 0.5
# 	Mutation rate: 0.625
# 	Mutation rate: 0.75
# 	Mutation rate: 0.875
# 	Mutation rate: 1.0

# %% [markdown]
# To calculate the condition specificity we will take it's value obtained after last step in each experiment and average it.

# %%
def get_avg_specificity_by_mutation_rate(performance):
    last_as_by_experiment = pd.DataFrame(performance
                                         .groupby(['experiment_id','mutation_rate'])['average_specificity']
                                         .last())
    last_as_by_experiment.reset_index(inplace=True)
    
    avg_as_by_mutation_rate = pd.DataFrame(last_as_by_experiment
                                           .groupby(['mutation_rate'])['average_specificity']
                                           .mean())
    avg_as_by_mutation_rate.reset_index(inplace=True)
    
    return avg_as_by_mutation_rate

# %% [markdown]
# See how the results look like

# %%
avg_as_by_mutation_rate = get_avg_specificity_by_mutation_rate(performance)
avg_as_by_mutation_rate
# Out:
#    mutation_rate  average_specificity
# 0          0.000             0.356527
# 1          0.125             0.356527
# 2          0.250             0.356527
# 3          0.375             0.356527
# 4          0.500             0.356527
# 5          0.625             0.356527
# 6          0.750             0.356527
# 7          0.875             0.356527
# 8          1.000             0.356527

# %%
fig = plt.figure(figsize=(15, 8), dpi=100)

plt.plot(avg_as_by_mutation_rate['mutation_rate'],
         avg_as_by_mutation_rate['average_specificity'], 'r', linewidth=2)
plt.title('Averaged specificity ratio')
plt.xlabel('Mutation rate')
plt.ylabel('Specificity')

plt.grid(True)
plt.show()
